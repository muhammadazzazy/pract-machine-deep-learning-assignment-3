# %% [markdown]
# <table align="center">
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/sherifmost/DeepLearning/blob/master/Labs/lab3/Lab3.ipynb">
#         <img src="http://introtodeeplearning.com/images/colab/colab.png?v2.0"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # Assignment 3: Convolutional Neural Network Use Cases

# %% [markdown]
# ![Simple CNN](https://github.com/sherifmost/DeepLearning/blob/master/Labs/lab3/Cover.png?raw=1)

# %% [markdown]
# ## 3.1 Problem Statement

# %% [markdown]
# In this assignment you will build several CNN models that check if a person is happy or not. You will use custom made CNN, and CNN use cases either pretrained or not, also you will apply layers freezing on pretrained CNNs and study all those modifications effect on the accuracy.

# %% [markdown]
# **IMPORTANT NOTE:** You have to change runtime type on Google Colab to GPU since the CNN models used require much computation resources and it will run very slowly on CPU (Default runtime type)
#
# Click on "Runtime" => "Change runtime type" => make sure that GPU is selected in the "Hardware accelerator"

# %% [markdown]
# ## 3.2 Problem Details

# %% [markdown]
# ### 3.2.1 Packages & Utility Methods

# %% [markdown]
# Make sure you check the imported modules as they can help you later on

# %%
import tensorflow as tf
import numpy as np
# you can use this library for resizing the images if you want
import cv2

from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from tensorflow.keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.utils import plot_model
from tensorflow.keras import applications
import tensorflow.keras.backend as K
K.set_image_data_format('channels_last')

from IPython.display import SVG
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

import pydot
import h5py
import random
import requests

# %matplotlib inline

# %%
def download_file(file_url):
    file_r = requests.get(file_url, allow_redirects=True)
    open(file_url.rsplit('/', 1)[1], 'wb').write(file_r.content)

# %% [markdown]
# ### 3.2.2 Dataset Loading

# %% [markdown]
# #### Define method to download & load dataset

# %%
def load_dataset():
    download_file("https://raw.githubusercontent.com/KhaledElTahan/DeepLearning/master/Labs/lab3/lab3_train.h5")
    download_file("https://raw.githubusercontent.com/KhaledElTahan/DeepLearning/master/Labs/lab3/lab3_test.h5")

    path_to_train = "lab3_train.h5"
    path_to_test = "lab3_test.h5"

    train_dataset = h5py.File(path_to_train, "r")
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test, "r")
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # reshape y from (samples, ) to (1, samples)
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_x.shape[0]))

    # transpose y
    train_y = train_y.T
    test_y = test_y.T

    return train_x, train_y, test_x, test_y

# %% [markdown]
# #### Define method to make simple preprocessing on the dataset

# %%
def preprocess_data():
    train_x, train_y, test_x, test_y = load_dataset()

    # Normalize image vectors
    train_x = train_x/255.
    test_x = test_x/255.

    print ("number of training examples = " + str(train_x.shape[0]))
    print ("number of test examples = " + str(test_x.shape[0]))

    print ("X_train shape: " + str(train_x.shape))
    print ("Y_train shape: " + str(train_y.shape))
    print ("X_test shape: " + str(test_x.shape))
    print ("Y_test shape: " + str(test_y.shape))

    return train_x, train_y, test_x, test_y

# %%
# Source: https://medium.com/@guntapallisuresh28/build-your-first-multi-label-image-classification-model-with-neural-network-d4d42d779ab4
def preprocess_data():
    train_x, train_y, test_x, test_y = load_dataset()
    resize_train_x = []
    resize_test_x = []

    # Normalize image vectors
    train_x = train_x/255.
    test_x = test_x/255.



    for i in range(train_x.shape[0]):
        temp_resize_train_x = cv2.resize(train_x[i], (75, 75))
        resize_train_x.append(temp_resize_train_x)

    train_x = np.array(resize_train_x)

    for i in range(test_x.shape[0]):
        temp_resize_test_x = cv2.resize(test_x[i], (75, 75))
        resize_test_x.append(temp_resize_test_x)

    test_x = np.array(resize_test_x)

    print ("number of training examples = " + str(train_x.shape[0]))
    print ("number of test examples = " + str(test_x.shape[0]))

    print ("X_train shape: " + str(train_x.shape))
    print ("Y_train shape: " + str(train_y.shape))
    print ("X_test shape: " + str(test_x.shape))
    print ("Y_test shape: " + str(test_y.shape))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# #### Get the preprocessed Data

# %%
# Obtaining the training and testing data
train_x, train_y, test_x, test_y = preprocess_data()
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 75, 75, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 75, 75, 3)
# Y_test shape: (150, 1)

# %% [markdown]
# ### 3.2.3 Dataset Visualization

# %%
W_grid = 6
L_grid = 6

fig, axes = plt.subplots(L_grid, W_grid, figsize = (9,9))

axes = axes.ravel() # flaten the L_grid x W_grid matrix into L_grid * W_grid array

n_training = len(train_x) # get the length of the training dataset

for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    index = np.random.randint(0, n_training)
    axes[i].imshow(train_x[index])

    if train_y[index] == 1:
        axes[i].set_title("Happy", fontsize = 10)
    else:
        axes[i].set_title("Not Happy", fontsize = 10)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### 3.2.4 Plot Utility Methods

# %% [markdown]
# The following code is used to plot accuracy and loss histories for each model experiment.

# %%
def plot(training_results, validation_results, results_type, model_name):
    fig = plt.figure(figsize=[8, 6])

    plt.plot(training_results, 'r', linewidth=3.0)
    plt.plot(validation_results, 'b', linewidth=3.0)
    plt.legend(['Training ' + results_type, 'Validation ' + results_type], fontsize=18)
    plt.xlabel('Epochs', fontsize=16)
    plt.ylabel(results_type, fontsize=16)
    plt.title(results_type + ' of ' + model_name, fontsize=16)


def plot_accuracy(history, model_name):
    plot(history.history['accuracy'], history.history['val_accuracy'], 'Accuracy', model_name)
    

def plot_loss(history, model_name):
    plot(history.history['loss'], history.history['val_loss'], 'Loss', model_name)

# %% [markdown]
# ### 3.2.5 Custom CNN Model

# %% [markdown]
# **TODO**: Build a custom CNN model to solve the problem.
#
# Model guidelines **(You need to follow them)**:
#
# 1. [Input](https://keras.io/api/layers/core_layers/input/) Layer.
# 2. [ZeroPadding2D](https://keras.io/api/layers/reshaping_layers/zero_padding2d/) Layer.
# 3. [Conv2D](https://keras.io/api/layers/convolution_layers/convolution2d/) Layer.
# 4. [BatchNormalization](https://keras.io/api/layers/normalization_layers/batch_normalization/) Layer. You can read [this article](https://kharshit.github.io/blog/2018/12/28/why-batch-normalization) to learn more about BatchNormalization.
# 5. Relu [Activation](https://keras.io/api/layers/core_layers/activation/).
# 6. [MaxPooling2D](https://keras.io/api/layers/pooling_layers/max_pooling2d/) Layer.
# 7. [Flatten](https://keras.io/api/layers/reshaping_layers/flatten/) Layer.
# 8. [Dense](https://keras.io/api/layers/core_layers/dense/) with Sigmoid activation (one perceptron).
#
# **Note**: If you made the required model, you can make other custom CNN models **if you wish** to further improve the accuracy, but in other code cells however.
#
# **Note**: the code provided below uses the tensorflow [functional API](https://www.tensorflow.org/guide/keras/functional) in building the model.

# %%
def CustomCNN(input_shape):
    """
    Implementation of the Custom CNN.
    Args:
        input_shape () shape of the images of the dataset
    Returns:
        model (Keras.Model): CNN Custom Model
        model_name (Str): The name of the model
    """
    
    ### START CODE HERE ###
    X_input = Input(input_shape)
    print(X_input.shape)

    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((3, 3))(X_input)

    # CONV -> BN -> RELU Block applied to X
    # Choose a suitable number of filters and kernel size
    X = tf.keras.layers.Conv2D(5, 5, input_shape=input_shape)(X)
    X = BatchNormalization(axis=3, name='bn0')(X)
    X = Activation('relu')(X)

    # MAXPOOL
    X = MaxPooling2D(pool_size = (3, 3))(X)
    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED (Dense)
    X = Flatten()(X)
    Y = Dense(1, activation='sigmoid')(X)

    # Create model. This creates your tensorflow.keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=Y)
    ### END CODE HERE ###
    
    return model, "Custom CNN"

# %% [markdown]
# ### 3.2.6 CNN Use Case No.1: VGG

# %% [markdown]
# ![VGG Architecture](https://github.com/sherifmost/DeepLearning/blob/master/Labs/lab3/vgg.png?raw=1)

# %% [markdown]
# **Note**: this ia a show case to help you do the same with other use cases.
#
# **TODO**: Try different variations for VGG:
#
# 1. [VGG16](https://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG16)
# 2. [VGG19](https://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG19)
#
# **Note**: *You will need to experiment all of them both pretrained (both with or without layers freezing) and also untrained, in the test section.*

# %%
def VGG(pretrained = True, input_shape = (64, 64, 3), model_name = "VGG16"):
    """
    Returns VGG Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        VGG(True) -> Model, "Pretrained VGG16"
    """
    if(pretrained):
        model_name = "Pretrained " + model_name
        base_model = applications.vgg19.VGG19(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        base_model = applications.vgg19.VGG19(weights=None, include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.7 CNN Use Case No.2: Residual Connections-based Networks

# %% [markdown]
# ![VGG vs ResNet](https://github.com/sherifmost/DeepLearning/blob/master/Labs/lab3/VGG_vs_ResNet.png?raw=1)

# %% [markdown]
# **TODO**: Follow the same style for the above mentioned VGG and experiment the following Networks:
#
# 1. [ResNet50](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet50)
# 2. [ResNet101](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet101)
# 3. [InceptionResNetV2](https://www.tensorflow.org/api_docs/python/tf/keras/applications/inception_resnet_v2/InceptionResNetV2) this network builds on the inception network architecture and incorporates [residual connections](https://towardsdatascience.com/what-is-residual-connection-efb07cab0d55), you can read more about it [here](https://paperswithcode.com/method/inception-resnet-v2#:~:text=Inception%2DResNet%2Dv2%20is%20a,stage%20of%20the%20Inception%20architecture).
#
# **Note 1**: *You will need to experiment all of them both pretrained (both with or without layers freezing) and also untrained, in the test section.*
#
# **Note 2**: For very deep networks like **InceptionResNetV2**, the size of the input might get reduced too much and an error might be produced, **you need to fix this issue by either resizing the images (preferred) or by adding padding (not preferred)**.
#
# To resize the image you *can* follow the following steps (*just some possible guidelines)*:
#
# *   You can use [cv2.resize](https://www.geeksforgeeks.org/image-resizing-using-opencv-python/) or [tf.image.resize](https://www.tensorflow.org/api_docs/python/tf/image/resize).
# *   Make a function similar to preprocess_data() but instead resize the train and test images before returning them at the end
# *   When you train the model that is causing the error, call the new function you made to obtain the training and testing data instead of calling the original preprocess_data() *(as was done at the beggining of the notebook)*

# %%
# The ResNet function refers to the above residual connection-based networks including the InceptionResNetV2 network
def ResNet(pretrained = True, input_shape = (75, 75, 3), model_name = "InceptionResNetV2"):
    """
    Returns ResNet Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        ResNet(True) -> Model, "Pretrained ResNet50"
    """
    if(pretrained):
        model_name = "Pretrained " + model_name
        base_model = applications.inception_resnet_v2.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        base_model = applications.inception_resnet_v2.InceptionResNetV2(weights=None, include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.8 CNN Use Case No.3: Your choice

# %% [markdown]
# **TODO**: Select one application other than VGG or ResNet from [here](https://www.tensorflow.org/api_docs/python/tf/keras/applications) and implement it the same way you did with VGG & ResNet.
#
# **Note**: *You will need to experiment it in both pretrained (both with or without layers freezing) and also untrained, in the test section.*

# %%
def CNN_App(pretrained = True, input_shape = (64, 64, 3), model_name = 'MobileNet'):
    """
    Returns A Custom CNN Application Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        CNN_App(True, (64, 64, 3), "Xception") -> Model, "Pretrained Xception"
    """
    if(pretrained):
        model_name = "Pretrained " + model_name
        base_model = applications.mobilenet.MobileNet(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        base_model = applications.mobilenet.MobileNet(weights=None, include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.9 Layers Freezing

# %% [markdown]
# The following utility method is used for layers freezing.

# %% [markdown]
# **TODO**: *Experiment all the pretrained models with layers freezing using* **different number of frozen layers**.
#
# **NOTE**: You will not change this method at all, the experimenting will take place in the test cases section below.

# %%
def freeze(model, number_of_frozen_layers):
    layers = model.layers

    layers = layers[:number_of_frozen_layers]

    for layer in layers:
        layer.trainable = False

    return model

# %% [markdown]
# ### 3.2.10 Make your models

# %% [markdown]
# You can use the following utility method to make the model you desire, **modify it if you please**.

# %%
def make_model(pretrained=True, freeze_layers=False, number_of_frozen_layers=0, model_selection="VGG"):
    """
    Use this method to create models
    Args:
      pretrained (Bool): Whether make the model pretrained or not, doesn't apply to custom CNN.
      freeze_layers (Bool): Whether apply layers freezing on pretrained networks or not.
      number_of_frozen_layers (int): Number of frozen layers.
      model_selection (Str): Must be exactly "Custom", or "VGG", or "ResNet" or anything else for CNN_App
    """
    # ==================================================================== TAKE CARE ==========================================================================
    # You might need to make the input shape an additional parameter to the function instead of being statically defined here
    # This will help you configure the input_shape when you handle the error due to the vanishing input dimensions in very deep networks like inception_resnetV2
    
    # input_shape = (64, 64, 3)
    input_shape = (75, 75, 3)
    
    if model_selection == "Custom":
        model, model_name = CustomCNN(input_shape)
    elif model_selection == "VGG":
        model, model_name = VGG(pretrained, input_shape)
    elif model_selection == "ResNet":
        model, model_name = ResNet(pretrained, input_shape)
    else:
        model, model_name = CNN_App(pretrained, input_shape)

    if model_selection != "Custom":
        if freeze_layers:
            model = freeze(model, number_of_frozen_layers)
            model_name = model_name + " with " + str(number_of_frozen_layers) + " Frozen Layers"

        ## Add classification head for non custom models
        y = model.output
        y = Flatten()(y)
        y = Dense(256, activation='relu')(y)
        y = Dense(1, activation='sigmoid', name='fc')(y)

        model = Model(inputs=model.input, outputs=y)

    return model, model_name

# %% [markdown]
# ### 3.2.11 Testing model utility method

# %% [markdown]
# This is a generic method that will be used to test all the implemented models, a modular design allows you to experiment more clearly. **Modify it if you please.**

# %% [markdown]
# **TODO**:
#
# 1. Try different [optimizers](https://keras.io/api/optimizers/) and report their affect on the **results** and plots.
# 2. For each optimizer, try different learning rates and other hyperparameters (If applicable), and report the difference on the **results** and plots.
# 3. Try different [loss functions](https://keras.io/api/losses/), and report their affect on **accuracy** and plots.
#
# **IMPORTANT NOTE**: You don't need to try different optimizers, learning rates and hyperparameters, and losses on all models, **just find the best model with the current optimizers, rates and hyperparameters & losses** **then try your experiments** (changing optimizers, rates and hyperparameters & losses) only on this best model.
#
# ***The best model is obtained after testing the different models defined above in different cases (untrained, pretrained without freezing, and pretrained with different number of frozen layers) and choosing the model case giving the best performance***

# %%
def test_model(model, model_name, epochs=10, print_summary=True, plot_results=True):
    '''TODO: Experiment with different optimizers, learning rates and hyperparameters, and losses on the best model'''

    sgd = tf.keras.optimizers.legacy.SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
    adam = tf.keras.optimizers.legacy.Adam(lr=0.0001)
    rmsprop = tf.keras.optimizers.legacy.RMSprop(lr=0.0001)

    model.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])

    if (print_summary):
        model.summary()

    hist = model.fit(train_x, train_y, validation_data = (test_x, test_y), verbose=1, epochs=epochs, batch_size=32)
    preds = model.evaluate(test_x, test_y, batch_size=32, verbose=1, sample_weight=None)

    print ("Validation Loss = " + str(preds[0]))
    print ("Validation Accuracy = " + str(preds[1]))

    if(plot_results):
        plot_loss(hist, model_name)
        plot_accuracy(hist, model_name)

# %% [markdown]
# ### 3.2.12 Create your model test cases.

# %% [markdown]
# **TODO**: Fill here all the test cases methods that you want to apply.
#
# Add methods (Untrained, pretrained & pretrained with freezing) for *(at least)*:
# 1. ResNet()
# 2. CNN_App()
#
# **NOTE**: *Those test cases, don't change use case types (i.e. you will need to change the VGG in VGG() method to VGG19 and re test again or make another function for VGG19 for example) and doesn't change the loss function nor the optimizer type (these need to be changed in the testing utility method).*

# %%
def test_custom_CNN(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "Custom")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_untrained_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, 7, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_untrained_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, 7, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_untrained_CNN_App(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "MobileNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_CNN_App(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "MobileNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_CNN_App(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, 7, "MobileNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %% [markdown]
# ###  3.2.13 Test your models

# %% [markdown]
# **TODO**: Call all your defined methods for testing here.
#
# **Note**: You might want to go up to **1000** epochs for the untrained model if the validation accuracy is low.

# %%
test_custom_CNN(20)
# Out:
# (None, 64, 64, 3)
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  zero_padding2d_2 (ZeroPaddi  (None, 70, 70, 3)        0
#  ng2D)
#
#  conv2d_2 (Conv2D)           (None, 66, 66, 5)         380
#
#  bn0 (BatchNormalization)    (None, 66, 66, 5)         20
#
#  activation_2 (Activation)   (None, 66, 66, 5)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 5)        0
#  2D)
#
#  flatten_7 (Flatten)         (None, 2420)              0
#
#  dense_7 (Dense)             (None, 1)                 2421
#
# =================================================================
# Total params: 2,821
# Trainable params: 2,811
# Non-trainable params: 10
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 1s 18ms/step - loss: 0.6694 - accuracy: 0.5967 - val_loss: 0.6936 - val_accuracy: 0.5267
# Epoch 2/20
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6350 - accuracy: 0.6483 - val_loss: 0.6907 - val_accuracy: 0.5467
# Epoch 3/20
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6051 - accuracy: 0.6817 - val_loss: 0.6839 - val_accuracy: 0.6200
# Epoch 4/20
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5765 - accuracy: 0.7233 - val_loss: 0.6751 - val_accuracy: 0.6533
# Epoch 5/20
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5545 - accuracy: 0.7650 - val_loss: 0.6646 - val_accuracy: 0.6533
# Epoch 6/20
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5361 - accuracy: 0.7467 - val_loss: 0.6475 - val_accuracy: 0.7133
# Epoch 7/20
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5152 - accuracy: 0.8100 - val_loss: 0.6376 - val_accuracy: 0.7067
# Epoch 8/20
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5011 - accuracy: 0.8100 - val_loss: 0.6215 - val_accuracy: 0.7600
# Epoch 9/20
# 19/19 [==============================] - 0s 10ms/step - loss: 0.4823 - accuracy: 0.8267 - val_loss: 0.6044 - val_accuracy: 0.7533
# Epoch 10/20
# 19/19 [==============================] - 0s 18ms/step - loss: 0.4694 - accuracy: 0.8500 - val_loss: 0.5884 - val_accuracy: 0.7867
# Epoch 11/20
# 17/19 [=========================>....] - ETA: 0s - loss: 0.4582 - accuracy: 0.8640
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-7b3af5bc0aee> in <module>
# ----> 1 test_custom_CNN(20)
#
# <ipython-input-80-e8c5210f6e79> in test_custom_CNN(epochs, print_summary, plot_results)
#       1 def test_custom_CNN(epochs=20, print_summary=True, plot_results=True):
#       2     model, model_name = make_model(False, False, 0, "Custom")
# ----> 3     test_model(model, model_name, epochs, print_summary, plot_results)
#
# <ipython-input-79-f260f538e59c> in test_model(model, model_name, epochs, print_summary, plot_results)
#       8         model.summary()
#       9
# ---> 10     hist = model.fit(train_x, train_y, validation_data = (test_x, test_y), verbose=1, epochs=epochs, batch_size=32)
#      11     preds = model.evaluate(test_x, test_y, batch_size=32, verbose=1, sample_weight=None)
#      12
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2048             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2049             # Override with model metrics instead of last step logs
# -> 2050             logs = self._validate_and_get_metrics_result(logs)
#    2051             callbacks.on_test_end(logs=logs)
#    2052
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in _validate_and_get_metrics_result(self, logs)
#    1183                 metric_logs.keys()
#    1184             ):
# -> 1185                 logs = tf_utils.sync_to_numpy_or_python_type(metric_logs)
#    1186             elif self._cluster_coordinator:
#    1187                 logging.warning(PSS_WARN_MSG)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     663         return t.item() if np.ndim(t) == 0 else t
#     664
# --> 665     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     666
#     667
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     656         # Don't turn ragged or sparse tensors to NumPy.
#     657         if isinstance(t, tf.Tensor):
# --> 658             t = t.numpy()
#     659         # Strings, ragged and sparse tensors don't have .item(). Return them
#     660         # as-is.
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1153     """
#    1154     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1155     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1156     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1157
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1119   def _numpy(self):
#    1120     try:
# -> 1121       return self._numpy_internal()
#    1122     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1123       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
test_untrained_VGG(100)

# %%
test_pretrained_VGG(20)

# %%
test_pretrained_layers_freezing_VGG(20)

# %%
test_untrained_ResNet(100)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 75, 75, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 37, 37, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 37, 37, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 37, 37, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 35, 35, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 35, 35, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 35, 35, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 35, 35, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 17, 17, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 17, 17, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 17, 17, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 17, 17, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 15, 15, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 15, 15, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 15, 15, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)   0           ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 64)     12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 64)    192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 7, 7, 64)     0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 48)     9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 96)     55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 7, 7, 48)    144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 96)    288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 7, 7, 48)     0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 7, 7, 96)     0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 7, 7, 192)   0           ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 96)     18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 64)     76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 96)     82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 64)     12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 96)    288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 64)    192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 96)    288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 64)    192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 7, 7, 96)     0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 7, 7, 64)     0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 7, 7, 320)    0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 7, 7, 32)    96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 48)     13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 7, 7, 32)    96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 7, 7, 48)    144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 7, 7, 48)     0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 32)     9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 7, 7, 64)     27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 7, 7, 32)    96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 7, 7, 32)    96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 7, 7, 64)    192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 7, 7, 320)    0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 7, 7, 320)    0           ['block35_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 7, 7, 32)    96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 7, 7, 48)     13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 7, 7, 32)    96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 7, 7, 48)    144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 7, 7, 48)     0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 7, 7, 32)     9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 7, 7, 64)     27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 7, 7, 32)    96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 7, 7, 32)    96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 7, 7, 64)    192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 7, 7, 320)    0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 7, 7, 320)    0           ['block35_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 32)    96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 48)     13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 7, 7, 32)    96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 48)    144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 7, 7, 48)     0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 7, 7, 32)     9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 64)     27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 7, 7, 32)    96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 32)    96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 64)    192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 7, 7, 320)    0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 7, 7, 320)    0           ['block35_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 32)    96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 48)     13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 32)    96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 48)    144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 7, 7, 48)     0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 32)     9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 64)     27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 32)    96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 32)    96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 64)    192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 7, 7, 320)    0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 7, 7, 320)    0           ['block35_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 7, 7, 32)    96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 7, 7, 48)     13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 7, 7, 32)    96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 7, 7, 48)    144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 7, 7, 48)     0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 7, 7, 32)     9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 7, 7, 64)     27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 7, 7, 32)    96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 7, 7, 32)    96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 7, 7, 64)    192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 7, 7, 320)    0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 7, 7, 320)    0           ['block35_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 32)    96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 48)     13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 32)    96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 48)    144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 7, 7, 48)     0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 7, 7, 32)     9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 64)     27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 32)    96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 32)    96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 64)    192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 7, 7, 320)    0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 7, 7, 320)    0           ['block35_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 32)    96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 48)     13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 32)    96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 48)    144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 7, 7, 48)     0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 32)     9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 64)     27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 32)    96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 32)    96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 7, 7, 64)    192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 7, 7, 320)    0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 7, 7, 320)    0           ['block35_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 32)     10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 7, 7, 32)    96          ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_57[0][0]']
#
# ...
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten (Flatten)              (None, 1536)         0           ['conv_7b_ac[0][0]']
#
#  dense (Dense)                  (None, 256)          393472      ['flatten[0][0]']
#
#  fc (Dense)                     (None, 1)            257         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 54,730,465
# Trainable params: 54,669,921
# Non-trainable params: 60,544
# __________________________________________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - 85s 523ms/step - loss: 0.6842 - accuracy: 0.7567 - val_loss: 1.3182 - val_accuracy: 0.4400
# Epoch 2/100
# 19/19 [==============================] - 3s 162ms/step - loss: 0.3103 - accuracy: 0.8833 - val_loss: 1.5442 - val_accuracy: 0.4400
# Epoch 3/100
# 19/19 [==============================] - 4s 189ms/step - loss: 0.2329 - accuracy: 0.9017 - val_loss: 0.9392 - val_accuracy: 0.4400
# Epoch 4/100
# 19/19 [==============================] - 3s 161ms/step - loss: 0.3477 - accuracy: 0.8783 - val_loss: 1.1887 - val_accuracy: 0.4400
# Epoch 5/100
# 19/19 [==============================] - 3s 169ms/step - loss: 0.1570 - accuracy: 0.9417 - val_loss: 1.0666 - val_accuracy: 0.4400
# Epoch 6/100
# 19/19 [==============================] - 3s 177ms/step - loss: 0.1780 - accuracy: 0.9150 - val_loss: 1.5010 - val_accuracy: 0.4400
# Epoch 7/100
# 19/19 [==============================] - 4s 188ms/step - loss: 0.1131 - accuracy: 0.9583 - val_loss: 0.9217 - val_accuracy: 0.4400
# Epoch 8/100
# 19/19 [==============================] - 3s 161ms/step - loss: 0.1053 - accuracy: 0.9633 - val_loss: 1.1481 - val_accuracy: 0.4400
# Epoch 9/100
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0718 - accuracy: 0.9767 - val_loss: 4.1078 - val_accuracy: 0.4400
# Epoch 10/100
# 19/19 [==============================] - 4s 188ms/step - loss: 0.0834 - accuracy: 0.9717 - val_loss: 5.0141 - val_accuracy: 0.4400
# Epoch 11/100
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0981 - accuracy: 0.9750 - val_loss: 1.6002 - val_accuracy: 0.4400
# Epoch 12/100
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0909 - accuracy: 0.9583 - val_loss: 1.7813 - val_accuracy: 0.4400
# Epoch 13/100
# 19/19 [==============================] - 3s 168ms/step - loss: 0.1167 - accuracy: 0.9700 - val_loss: 2.3333 - val_accuracy: 0.4400
# Epoch 14/100
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0652 - accuracy: 0.9800 - val_loss: 2.5834 - val_accuracy: 0.4400
# Epoch 15/100
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0560 - accuracy: 0.9850 - val_loss: 0.9721 - val_accuracy: 0.4867
# Epoch 16/100
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0453 - accuracy: 0.9867 - val_loss: 1.4045 - val_accuracy: 0.5067
# Epoch 17/100
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0759 - accuracy: 0.9717 - val_loss: 1.7669 - val_accuracy: 0.5600
# Epoch 18/100
# 19/19 [==============================] - 4s 198ms/step - loss: 0.0345 - accuracy: 0.9850 - val_loss: 0.9889 - val_accuracy: 0.5733
# Epoch 19/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0460 - accuracy: 0.9800 - val_loss: 1.6270 - val_accuracy: 0.5600
# Epoch 20/100
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0210 - accuracy: 0.9900 - val_loss: 0.6847 - val_accuracy: 0.6267
# Epoch 21/100
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0278 - accuracy: 0.9950 - val_loss: 0.8579 - val_accuracy: 0.7400
# Epoch 22/100
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0441 - accuracy: 0.9767 - val_loss: 2.0129 - val_accuracy: 0.5400
# Epoch 23/100
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0213 - accuracy: 0.9917 - val_loss: 1.1174 - val_accuracy: 0.7267
# Epoch 24/100
# 19/19 [==============================] - 3s 168ms/step - loss: 0.1535 - accuracy: 0.9683 - val_loss: 4.7986 - val_accuracy: 0.5333
# Epoch 25/100
# 19/19 [==============================] - 4s 198ms/step - loss: 0.0426 - accuracy: 0.9933 - val_loss: 2.2951 - val_accuracy: 0.4800
# Epoch 26/100
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.2102 - val_accuracy: 0.9000
# Epoch 27/100
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.5714 - val_accuracy: 0.7267
# Epoch 28/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0269 - accuracy: 0.9967 - val_loss: 0.5486 - val_accuracy: 0.8333
# Epoch 29/100
# 19/19 [==============================] - 4s 196ms/step - loss: 0.0065 - accuracy: 0.9967 - val_loss: 0.3150 - val_accuracy: 0.8933
# Epoch 30/100
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0736 - accuracy: 0.9867 - val_loss: 0.3401 - val_accuracy: 0.9000
# Epoch 31/100
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0521 - accuracy: 0.9800 - val_loss: 0.1996 - val_accuracy: 0.9333
# Epoch 32/100
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0189 - accuracy: 0.9917 - val_loss: 0.7691 - val_accuracy: 0.7600
# Epoch 33/100
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0251 - accuracy: 0.9933 - val_loss: 0.0832 - val_accuracy: 0.9600
# Epoch 34/100
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0306 - accuracy: 0.9950 - val_loss: 0.0547 - val_accuracy: 0.9800
# Epoch 35/100
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0109 - accuracy: 0.9983 - val_loss: 0.1152 - val_accuracy: 0.9533
# Epoch 36/100
# 19/19 [==============================] - 4s 193ms/step - loss: 0.0037 - accuracy: 0.9983 - val_loss: 0.1725 - val_accuracy: 0.9533
# Epoch 37/100
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0314 - accuracy: 0.9933 - val_loss: 0.3100 - val_accuracy: 0.9200
# Epoch 38/100
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0216 - accuracy: 0.9917 - val_loss: 0.0825 - val_accuracy: 0.9733
# Epoch 39/100
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0546 - accuracy: 0.9850 - val_loss: 0.7662 - val_accuracy: 0.8267
# Epoch 40/100
# 19/19 [==============================] - 4s 201ms/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.2920 - val_accuracy: 0.9267
# Epoch 41/100
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.2278 - val_accuracy: 0.9333
# Epoch 42/100
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 1.4110 - val_accuracy: 0.6867
# Epoch 43/100
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0541 - accuracy: 0.9850 - val_loss: 0.2853 - val_accuracy: 0.9467
# Epoch 44/100
# 19/19 [==============================] - 4s 194ms/step - loss: 0.0034 - accuracy: 0.9983 - val_loss: 0.1503 - val_accuracy: 0.9600
# Epoch 45/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0053 - accuracy: 0.9967 - val_loss: 0.1230 - val_accuracy: 0.9600
# Epoch 46/100
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0054 - accuracy: 0.9967 - val_loss: 0.8256 - val_accuracy: 0.8200
# Epoch 47/100
# 19/19 [==============================] - 3s 186ms/step - loss: 0.0765 - accuracy: 0.9883 - val_loss: 0.2435 - val_accuracy: 0.8933
# Epoch 48/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.1105 - val_accuracy: 0.9667
# Epoch 49/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9533
# Epoch 50/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.1211 - val_accuracy: 0.9733
# Epoch 51/100
# 19/19 [==============================] - 4s 194ms/step - loss: 0.0035 - accuracy: 0.9967 - val_loss: 0.0575 - val_accuracy: 0.9667
# Epoch 52/100
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0029 - accuracy: 0.9967 - val_loss: 0.0399 - val_accuracy: 0.9867
# Epoch 53/100
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3604 - val_accuracy: 0.8933
# Epoch 54/100
# 19/19 [==============================] - 3s 161ms/step - loss: 5.3802e-04 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.8400
# Epoch 55/100
# 19/19 [==============================] - 4s 200ms/step - loss: 0.0282 - accuracy: 0.9900 - val_loss: 1.7368 - val_accuracy: 0.6133
# Epoch 56/100
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0674 - accuracy: 0.9867 - val_loss: 0.2040 - val_accuracy: 0.9533
# Epoch 57/100
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9733
# Epoch 58/100
# 19/19 [==============================] - 3s 183ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9533
# Epoch 59/100
# 19/19 [==============================] - 4s 183ms/step - loss: 1.2467e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9600
# Epoch 60/100
# 19/19 [==============================] - 3s 164ms/step - loss: 5.2857e-05 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9400
# Epoch 61/100
# 19/19 [==============================] - 3s 163ms/step - loss: 3.6386e-04 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9400
# Epoch 62/100
# 19/19 [==============================] - 4s 201ms/step - loss: 5.8158e-04 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9667
# Epoch 63/100
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9563 - val_accuracy: 0.7800
# Epoch 64/100
# 19/19 [==============================] - 3s 164ms/step - loss: 6.1659e-04 - accuracy: 1.0000 - val_loss: 0.2330 - val_accuracy: 0.9667
# Epoch 65/100
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0313 - accuracy: 0.9917 - val_loss: 0.6613 - val_accuracy: 0.8867
# Epoch 66/100
# 19/19 [==============================] - 4s 196ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3545 - val_accuracy: 0.9400
# Epoch 67/100
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0481 - accuracy: 0.9850 - val_loss: 0.6992 - val_accuracy: 0.8733
# Epoch 68/100
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0115 - accuracy: 0.9950 - val_loss: 0.8484 - val_accuracy: 0.8533
# Epoch 69/100
# 19/19 [==============================] - 3s 182ms/step - loss: 0.0156 - accuracy: 0.9933 - val_loss: 0.3900 - val_accuracy: 0.9600
# Epoch 70/100
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0078 - accuracy: 0.9967 - val_loss: 0.0949 - val_accuracy: 0.9667
# Epoch 71/100
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0390 - accuracy: 0.9900 - val_loss: 0.1637 - val_accuracy: 0.9600
# Epoch 72/100
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9533
# Epoch 73/100
# 19/19 [==============================] - 4s 193ms/step - loss: 4.7405e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9867
# Epoch 74/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0220 - accuracy: 0.9950 - val_loss: 0.0989 - val_accuracy: 0.9733
# Epoch 75/100
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0022 - accuracy: 0.9983 - val_loss: 0.1608 - val_accuracy: 0.9667
# Epoch 76/100
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0022 - accuracy: 0.9983 - val_loss: 0.1408 - val_accuracy: 0.9667
# Epoch 77/100
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9333
# Epoch 78/100
# 19/19 [==============================] - 3s 170ms/step - loss: 2.7226e-04 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9667
# Epoch 79/100
# 19/19 [==============================] - 3s 165ms/step - loss: 3.7927e-04 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9867
# Epoch 80/100
# 19/19 [==============================] - 3s 177ms/step - loss: 4.6052e-05 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9867
# Epoch 81/100
# 19/19 [==============================] - 3s 181ms/step - loss: 4.2398e-04 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9533
# Epoch 82/100
# 19/19 [==============================] - 3s 165ms/step - loss: 1.4670e-05 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9667
# Epoch 83/100
# 19/19 [==============================] - 3s 164ms/step - loss: 1.4216e-05 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9733
# Epoch 84/100
# 19/19 [==============================] - 3s 185ms/step - loss: 1.7739e-05 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9667
# Epoch 85/100
# 19/19 [==============================] - 3s 177ms/step - loss: 7.2994e-05 - accuracy: 1.0000 - val_loss: 0.1944 - val_accuracy: 0.9533
# Epoch 86/100
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0038 - accuracy: 0.9967 - val_loss: 0.3345 - val_accuracy: 0.8667
# Epoch 87/100
# 19/19 [==============================] - 3s 159ms/step - loss: 3.8896e-04 - accuracy: 1.0000 - val_loss: 0.6211 - val_accuracy: 0.7800
# Epoch 88/100
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0069 - accuracy: 0.9967 - val_loss: 0.5957 - val_accuracy: 0.8933
# Epoch 89/100
# 19/19 [==============================] - 3s 162ms/step - loss: 9.7558e-05 - accuracy: 1.0000 - val_loss: 0.4676 - val_accuracy: 0.9067
# Epoch 90/100
# 19/19 [==============================] - 3s 162ms/step - loss: 8.6136e-04 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 0.9733
# Epoch 91/100
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0109 - accuracy: 0.9950 - val_loss: 1.1694 - val_accuracy: 0.7400
# Epoch 92/100
# 19/19 [==============================] - 4s 202ms/step - loss: 0.0219 - accuracy: 0.9950 - val_loss: 2.7663 - val_accuracy: 0.5800
# Epoch 93/100
# 19/19 [==============================] - 3s 167ms/step - loss: 2.2946e-04 - accuracy: 1.0000 - val_loss: 1.3606 - val_accuracy: 0.6933
# Epoch 94/100
# 19/19 [==============================] - 3s 159ms/step - loss: 1.8985e-04 - accuracy: 1.0000 - val_loss: 0.5692 - val_accuracy: 0.8133
# Epoch 95/100
# 19/19 [==============================] - 3s 173ms/step - loss: 6.1013e-04 - accuracy: 1.0000 - val_loss: 0.3442 - val_accuracy: 0.9333
# Epoch 96/100
# 19/19 [==============================] - 3s 180ms/step - loss: 3.9740e-05 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9667
# Epoch 97/100
# 19/19 [==============================] - 3s 167ms/step - loss: 2.1331e-05 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9800
# Epoch 98/100
# 19/19 [==============================] - 3s 162ms/step - loss: 1.1511e-05 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9800
# Epoch 99/100
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0059 - accuracy: 0.9950 - val_loss: 0.3346 - val_accuracy: 0.9133
# Epoch 100/100
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0273 - accuracy: 0.9933 - val_loss: 0.6253 - val_accuracy: 0.9333
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6253 - accuracy: 0.9333
# Validation Loss = 0.6253272294998169
# Validation Accuracy = 0.9333333373069763

# %%
test_pretrained_ResNet(20)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 75, 75, 3)]  0           []
#
#  conv2d_203 (Conv2D)            (None, 37, 37, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_203 (Batch  (None, 37, 37, 32)  96          ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 35, 35, 32)  96          ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_204[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 35, 35, 64)   18432       ['activation_204[0][0]']
#
#  batch_normalization_205 (Batch  (None, 35, 35, 64)  192         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_205[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 17, 17, 64)  0           ['activation_205[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 17, 17, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_206 (Batch  (None, 17, 17, 80)  240         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 17, 17, 80)   0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 15, 15, 192)  138240      ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 15, 15, 192)  576        ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 15, 15, 192)  0           ['batch_normalization_207[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 192)   0           ['activation_207[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_211 (Batch  (None, 7, 7, 64)    192         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_211[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 7, 7, 48)     9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_211[0][0]']
#
#  batch_normalization_209 (Batch  (None, 7, 7, 48)    144         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 7, 7, 96)    288         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_212[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 7, 7, 192)   0           ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_208 (Conv2D)            (None, 7, 7, 96)     18432       ['max_pooling2d_5[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_209[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_212[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 7, 7, 64)     12288       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_208 (Batch  (None, 7, 7, 96)    288         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 7, 7, 64)    192         ['conv2d_210[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 7, 7, 96)    288         ['conv2d_213[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 7, 7, 64)    192         ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_208[0][0]']
#
#  activation_210 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_210[0][0]']
#
#  activation_213 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_214[0][0]']
#
#  mixed_5b (Concatenate)         (None, 7, 7, 320)    0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  batch_normalization_218 (Batch  (None, 7, 7, 32)    96          ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_218[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_218[0][0]']
#
#  batch_normalization_216 (Batch  (None, 7, 7, 32)    96          ['conv2d_216[0][0]']
#  Normalization)
#
#  batch_normalization_219 (Batch  (None, 7, 7, 48)    144         ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_216[0][0]']
#
#  activation_219 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_219[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_216[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_219[0][0]']
#
#  batch_normalization_215 (Batch  (None, 7, 7, 32)    96          ['conv2d_215[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 7, 7, 32)    96          ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_220 (Batch  (None, 7, 7, 64)    192         ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_215[0][0]']
#
#  activation_217 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_217[0][0]']
#
#  activation_220 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_220[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 7, 7, 320)    0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 7, 7, 320)    0           ['block35_1[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_224 (Batch  (None, 7, 7, 32)    96          ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_224[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_224[0][0]']
#
#  batch_normalization_222 (Batch  (None, 7, 7, 32)    96          ['conv2d_222[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 7, 7, 48)    144         ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_222[0][0]']
#
#  activation_225 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_225[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_222[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_225[0][0]']
#
#  batch_normalization_221 (Batch  (None, 7, 7, 32)    96          ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 7, 7, 32)    96          ['conv2d_223[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 7, 7, 64)    192         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_221[0][0]']
#
#  activation_223 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_223[0][0]']
#
#  activation_226 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_226[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_221[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 7, 7, 320)    0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 7, 7, 320)    0           ['block35_2[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_230 (Batch  (None, 7, 7, 32)    96          ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_230[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_230[0][0]']
#
#  batch_normalization_228 (Batch  (None, 7, 7, 32)    96          ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 7, 7, 48)    144         ['conv2d_231[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_231[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_228[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_231[0][0]']
#
#  batch_normalization_227 (Batch  (None, 7, 7, 32)    96          ['conv2d_227[0][0]']
#  Normalization)
#
#  batch_normalization_229 (Batch  (None, 7, 7, 32)    96          ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 7, 7, 64)    192         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_227[0][0]']
#
#  activation_229 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_229[0][0]']
#
#  activation_232 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_232[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 7, 7, 320)    0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 7, 7, 320)    0           ['block35_3[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_236 (Batch  (None, 7, 7, 32)    96          ['conv2d_236[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_236[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_236[0][0]']
#
#  batch_normalization_234 (Batch  (None, 7, 7, 32)    96          ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 7, 7, 48)    144         ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_234[0][0]']
#
#  activation_237 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_237[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_234[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_237[0][0]']
#
#  batch_normalization_233 (Batch  (None, 7, 7, 32)    96          ['conv2d_233[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 7, 7, 32)    96          ['conv2d_235[0][0]']
#  Normalization)
#
#  batch_normalization_238 (Batch  (None, 7, 7, 64)    192         ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_233[0][0]']
#
#  activation_235 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_235[0][0]']
#
#  activation_238 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_238[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_233[0][0]',
#                                                                   'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 7, 7, 320)    0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 7, 7, 320)    0           ['block35_4[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_242 (Batch  (None, 7, 7, 32)    96          ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_242[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_242[0][0]']
#
#  batch_normalization_240 (Batch  (None, 7, 7, 32)    96          ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 7, 7, 48)    144         ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_240[0][0]']
#
#  activation_243 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_240[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 7, 7, 32)    96          ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 7, 7, 32)    96          ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 7, 7, 64)    192         ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_239[0][0]']
#
#  activation_241 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_241[0][0]']
#
#  activation_244 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_244[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_239[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 7, 7, 320)    0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 7, 7, 320)    0           ['block35_5[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_248 (Batch  (None, 7, 7, 32)    96          ['conv2d_248[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_248[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_248[0][0]']
#
#  batch_normalization_246 (Batch  (None, 7, 7, 32)    96          ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_249 (Batch  (None, 7, 7, 48)    144         ['conv2d_249[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_246[0][0]']
#
#  activation_249 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_249[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_246[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_249[0][0]']
#
#  batch_normalization_245 (Batch  (None, 7, 7, 32)    96          ['conv2d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 7, 7, 32)    96          ['conv2d_247[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 7, 7, 64)    192         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_245[0][0]']
#
#  activation_247 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_247[0][0]']
#
#  activation_250 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_250[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_245[0][0]',
#                                                                   'activation_247[0][0]',
#                                                                   'activation_250[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 7, 7, 320)    0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 7, 7, 320)    0           ['block35_6[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_254 (Batch  (None, 7, 7, 32)    96          ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_254[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_254[0][0]']
#
#  batch_normalization_252 (Batch  (None, 7, 7, 32)    96          ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 7, 7, 48)    144         ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_252[0][0]']
#
#  activation_255 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_255[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_252[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_255[0][0]']
#
#  batch_normalization_251 (Batch  (None, 7, 7, 32)    96          ['conv2d_251[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 7, 7, 32)    96          ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 7, 7, 64)    192         ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_251[0][0]']
#
#  activation_253 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_256[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_251[0][0]',
#                                                                   'activation_253[0][0]',
#                                                                   'activation_256[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 7, 7, 320)    0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 7, 7, 320)    0           ['block35_7[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_260 (Batch  (None, 7, 7, 32)    96          ['conv2d_260[0][0]']
#  Normalization)
#
#  activation_260 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_260[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_7_ac[0][0]']
#
# ...
#  Normalization)
#
#  activation_390 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_393[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_390[0][0]',
#                                                                   'activation_393[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 1, 1, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_395 (Batch  (None, 1, 1, 192)   576         ['conv2d_395[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_395[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_395[0][0]']
#
#  batch_normalization_396 (Batch  (None, 1, 1, 224)   672         ['conv2d_396[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_396[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_396[0][0]']
#
#  batch_normalization_394 (Batch  (None, 1, 1, 192)   576         ['conv2d_394[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 1, 1, 256)   768         ['conv2d_397[0][0]']
#  Normalization)
#
#  activation_394 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_394[0][0]']
#
#  activation_397 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_397[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_394[0][0]',
#                                                                   'activation_397[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 1, 1, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_399 (Batch  (None, 1, 1, 192)   576         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_399[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_399[0][0]']
#
#  batch_normalization_400 (Batch  (None, 1, 1, 224)   672         ['conv2d_400[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_400[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_400[0][0]']
#
#  batch_normalization_398 (Batch  (None, 1, 1, 192)   576         ['conv2d_398[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 1, 1, 256)   768         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_398[0][0]']
#
#  activation_401 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_401[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_398[0][0]',
#                                                                   'activation_401[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 1, 1, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_403 (Batch  (None, 1, 1, 192)   576         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 1, 1, 224)   672         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_404[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 1, 1, 192)   576         ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 1, 1, 256)   768         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_405[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 1, 448)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 1, 1, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 1, 1, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 1, 1, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1, 1536)  4608        ['conv_7b[0][0]']
# 19/19 [==============================] - 74s 377ms/step - loss: 0.6917 - accuracy: 0.7983 - val_loss: 0.5260 - val_accuracy: 0.8200
# Epoch 2/20
# 19/19 [==============================] - 3s 171ms/step - loss: 0.1738 - accuracy: 0.9300 - val_loss: 0.3614 - val_accuracy: 0.8133
# Epoch 3/20
# 19/19 [==============================] - 3s 162ms/step - loss: 0.1088 - accuracy: 0.9733 - val_loss: 0.2290 - val_accuracy: 0.8867
# Epoch 4/20
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0730 - accuracy: 0.9850 - val_loss: 0.0605 - val_accuracy: 0.9867
# Epoch 5/20
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0531 - accuracy: 0.9900 - val_loss: 0.2194 - val_accuracy: 0.9533
# Epoch 6/20
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0868 - accuracy: 0.9700 - val_loss: 0.0724 - val_accuracy: 0.9733
# Epoch 7/20
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0851 - accuracy: 0.9750 - val_loss: 0.1808 - val_accuracy: 0.9267
# Epoch 8/20
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0709 - accuracy: 0.9933 - val_loss: 0.0867 - val_accuracy: 0.9867
# Epoch 9/20
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0216 - accuracy: 0.9967 - val_loss: 0.0582 - val_accuracy: 0.9933
# Epoch 10/20
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0481 - val_accuracy: 0.9933
# Epoch 11/20
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0086 - accuracy: 0.9983 - val_loss: 0.0982 - val_accuracy: 0.9800
# Epoch 12/20
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.5395 - val_accuracy: 0.8933
# Epoch 13/20
# 19/19 [==============================] - 4s 185ms/step - loss: 0.0361 - accuracy: 0.9867 - val_loss: 0.2536 - val_accuracy: 0.9400
# Epoch 14/20
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0370 - accuracy: 0.9950 - val_loss: 0.3978 - val_accuracy: 0.9133
# Epoch 15/20
# 19/19 [==============================] - 3s 171ms/step - loss: 3.1913e-04 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9800
# Epoch 16/20
# 19/19 [==============================] - 4s 196ms/step - loss: 3.8911e-04 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9933
# Epoch 17/20
# 19/19 [==============================] - 3s 166ms/step - loss: 2.1175e-04 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9933
# Epoch 18/20
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0203 - accuracy: 0.9900 - val_loss: 0.1556 - val_accuracy: 0.9867
# Epoch 19/20
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.1562 - val_accuracy: 0.9733
# Epoch 20/20
# 19/19 [==============================] - 4s 196ms/step - loss: 0.0107 - accuracy: 0.9950 - val_loss: 0.1803 - val_accuracy: 0.9867
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1803 - accuracy: 0.9867
# Validation Loss = 0.1803213655948639
# Validation Accuracy = 0.9866666793823242

# %%
test_pretrained_layers_freezing_ResNet(20)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 75, 75, 3)]  0           []
#
#  conv2d_609 (Conv2D)            (None, 37, 37, 32)   864         ['input_4[0][0]']
#
#  batch_normalization_609 (Batch  (None, 37, 37, 32)  96          ['conv2d_609[0][0]']
#  Normalization)
#
#  activation_609 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_609[0][0]']
#
#  conv2d_610 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_609[0][0]']
#
#  batch_normalization_610 (Batch  (None, 35, 35, 32)  96          ['conv2d_610[0][0]']
#  Normalization)
#
#  activation_610 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_610[0][0]']
#
#  conv2d_611 (Conv2D)            (None, 35, 35, 64)   18432       ['activation_610[0][0]']
#
#  batch_normalization_611 (Batch  (None, 35, 35, 64)  192         ['conv2d_611[0][0]']
#  Normalization)
#
#  activation_611 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_611[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 17, 17, 64)  0           ['activation_611[0][0]']
#  )
#
#  conv2d_612 (Conv2D)            (None, 17, 17, 80)   5120        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_612 (Batch  (None, 17, 17, 80)  240         ['conv2d_612[0][0]']
#  Normalization)
#
#  activation_612 (Activation)    (None, 17, 17, 80)   0           ['batch_normalization_612[0][0]']
#
#  conv2d_613 (Conv2D)            (None, 15, 15, 192)  138240      ['activation_612[0][0]']
#
#  batch_normalization_613 (Batch  (None, 15, 15, 192)  576        ['conv2d_613[0][0]']
#  Normalization)
#
#  activation_613 (Activation)    (None, 15, 15, 192)  0           ['batch_normalization_613[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 7, 7, 192)   0           ['activation_613[0][0]']
#  )
#
#  conv2d_617 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_617 (Batch  (None, 7, 7, 64)    192         ['conv2d_617[0][0]']
#  Normalization)
#
#  activation_617 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_617[0][0]']
#
#  conv2d_615 (Conv2D)            (None, 7, 7, 48)     9216        ['max_pooling2d_13[0][0]']
#
#  conv2d_618 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_617[0][0]']
#
#  batch_normalization_615 (Batch  (None, 7, 7, 48)    144         ['conv2d_615[0][0]']
#  Normalization)
#
#  batch_normalization_618 (Batch  (None, 7, 7, 96)    288         ['conv2d_618[0][0]']
#  Normalization)
#
#  activation_615 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_615[0][0]']
#
#  activation_618 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_618[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 7, 7, 192)   0           ['max_pooling2d_13[0][0]']
#  oling2D)
#
#  conv2d_614 (Conv2D)            (None, 7, 7, 96)     18432       ['max_pooling2d_13[0][0]']
#
#  conv2d_616 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_615[0][0]']
#
#  conv2d_619 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_618[0][0]']
#
#  conv2d_620 (Conv2D)            (None, 7, 7, 64)     12288       ['average_pooling2d_3[0][0]']
#
#  batch_normalization_614 (Batch  (None, 7, 7, 96)    288         ['conv2d_614[0][0]']
#  Normalization)
#
#  batch_normalization_616 (Batch  (None, 7, 7, 64)    192         ['conv2d_616[0][0]']
#  Normalization)
#
#  batch_normalization_619 (Batch  (None, 7, 7, 96)    288         ['conv2d_619[0][0]']
#  Normalization)
#
#  batch_normalization_620 (Batch  (None, 7, 7, 64)    192         ['conv2d_620[0][0]']
#  Normalization)
#
#  activation_614 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_614[0][0]']
#
#  activation_616 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_616[0][0]']
#
#  activation_619 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_619[0][0]']
#
#  activation_620 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_620[0][0]']
#
#  mixed_5b (Concatenate)         (None, 7, 7, 320)    0           ['activation_614[0][0]',
#                                                                   'activation_616[0][0]',
#                                                                   'activation_619[0][0]',
#                                                                   'activation_620[0][0]']
#
#  conv2d_624 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  batch_normalization_624 (Batch  (None, 7, 7, 32)    96          ['conv2d_624[0][0]']
#  Normalization)
#
#  activation_624 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_624[0][0]']
#
#  conv2d_622 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_625 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_624[0][0]']
#
#  batch_normalization_622 (Batch  (None, 7, 7, 32)    96          ['conv2d_622[0][0]']
#  Normalization)
#
#  batch_normalization_625 (Batch  (None, 7, 7, 48)    144         ['conv2d_625[0][0]']
#  Normalization)
#
#  activation_622 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_622[0][0]']
#
#  activation_625 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_625[0][0]']
#
#  conv2d_621 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_623 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_622[0][0]']
#
#  conv2d_626 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_625[0][0]']
#
#  batch_normalization_621 (Batch  (None, 7, 7, 32)    96          ['conv2d_621[0][0]']
#  Normalization)
#
#  batch_normalization_623 (Batch  (None, 7, 7, 32)    96          ['conv2d_623[0][0]']
#  Normalization)
#
#  batch_normalization_626 (Batch  (None, 7, 7, 64)    192         ['conv2d_626[0][0]']
#  Normalization)
#
#  activation_621 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_621[0][0]']
#
#  activation_623 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_623[0][0]']
#
#  activation_626 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_626[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_621[0][0]',
#                                                                   'activation_623[0][0]',
#                                                                   'activation_626[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 7, 7, 320)    0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 7, 7, 320)    0           ['block35_1[0][0]']
#
#  conv2d_630 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_630 (Batch  (None, 7, 7, 32)    96          ['conv2d_630[0][0]']
#  Normalization)
#
#  activation_630 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_630[0][0]']
#
#  conv2d_628 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_631 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_630[0][0]']
#
#  batch_normalization_628 (Batch  (None, 7, 7, 32)    96          ['conv2d_628[0][0]']
#  Normalization)
#
#  batch_normalization_631 (Batch  (None, 7, 7, 48)    144         ['conv2d_631[0][0]']
#  Normalization)
#
#  activation_628 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_628[0][0]']
#
#  activation_631 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_631[0][0]']
#
#  conv2d_627 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_629 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_628[0][0]']
#
#  conv2d_632 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_631[0][0]']
#
#  batch_normalization_627 (Batch  (None, 7, 7, 32)    96          ['conv2d_627[0][0]']
#  Normalization)
#
#  batch_normalization_629 (Batch  (None, 7, 7, 32)    96          ['conv2d_629[0][0]']
#  Normalization)
#
#  batch_normalization_632 (Batch  (None, 7, 7, 64)    192         ['conv2d_632[0][0]']
#  Normalization)
#
#  activation_627 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_627[0][0]']
#
#  activation_629 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_629[0][0]']
#
#  activation_632 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_632[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_627[0][0]',
#                                                                   'activation_629[0][0]',
#                                                                   'activation_632[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 7, 7, 320)    0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 7, 7, 320)    0           ['block35_2[0][0]']
#
#  conv2d_636 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_636 (Batch  (None, 7, 7, 32)    96          ['conv2d_636[0][0]']
#  Normalization)
#
#  activation_636 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_636[0][0]']
#
#  conv2d_634 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_637 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_636[0][0]']
#
#  batch_normalization_634 (Batch  (None, 7, 7, 32)    96          ['conv2d_634[0][0]']
#  Normalization)
#
#  batch_normalization_637 (Batch  (None, 7, 7, 48)    144         ['conv2d_637[0][0]']
#  Normalization)
#
#  activation_634 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_634[0][0]']
#
#  activation_637 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_637[0][0]']
#
#  conv2d_633 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_635 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_634[0][0]']
#
#  conv2d_638 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_637[0][0]']
#
#  batch_normalization_633 (Batch  (None, 7, 7, 32)    96          ['conv2d_633[0][0]']
#  Normalization)
#
#  batch_normalization_635 (Batch  (None, 7, 7, 32)    96          ['conv2d_635[0][0]']
#  Normalization)
#
#  batch_normalization_638 (Batch  (None, 7, 7, 64)    192         ['conv2d_638[0][0]']
#  Normalization)
#
#  activation_633 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_633[0][0]']
#
#  activation_635 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_635[0][0]']
#
#  activation_638 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_638[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_633[0][0]',
#                                                                   'activation_635[0][0]',
#                                                                   'activation_638[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 7, 7, 320)    0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 7, 7, 320)    0           ['block35_3[0][0]']
#
#  conv2d_642 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_642 (Batch  (None, 7, 7, 32)    96          ['conv2d_642[0][0]']
#  Normalization)
#
#  activation_642 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_642[0][0]']
#
#  conv2d_640 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_643 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_642[0][0]']
#
#  batch_normalization_640 (Batch  (None, 7, 7, 32)    96          ['conv2d_640[0][0]']
#  Normalization)
#
#  batch_normalization_643 (Batch  (None, 7, 7, 48)    144         ['conv2d_643[0][0]']
#  Normalization)
#
#  activation_640 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_640[0][0]']
#
#  activation_643 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_643[0][0]']
#
#  conv2d_639 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_641 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_640[0][0]']
#
#  conv2d_644 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_643[0][0]']
#
#  batch_normalization_639 (Batch  (None, 7, 7, 32)    96          ['conv2d_639[0][0]']
#  Normalization)
#
#  batch_normalization_641 (Batch  (None, 7, 7, 32)    96          ['conv2d_641[0][0]']
#  Normalization)
#
#  batch_normalization_644 (Batch  (None, 7, 7, 64)    192         ['conv2d_644[0][0]']
#  Normalization)
#
#  activation_639 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_639[0][0]']
#
#  activation_641 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_641[0][0]']
#
#  activation_644 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_644[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_639[0][0]',
#                                                                   'activation_641[0][0]',
#                                                                   'activation_644[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 7, 7, 320)    0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 7, 7, 320)    0           ['block35_4[0][0]']
#
#  conv2d_648 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_648 (Batch  (None, 7, 7, 32)    96          ['conv2d_648[0][0]']
#  Normalization)
#
#  activation_648 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_648[0][0]']
#
#  conv2d_646 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_649 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_648[0][0]']
#
#  batch_normalization_646 (Batch  (None, 7, 7, 32)    96          ['conv2d_646[0][0]']
#  Normalization)
#
#  batch_normalization_649 (Batch  (None, 7, 7, 48)    144         ['conv2d_649[0][0]']
#  Normalization)
#
#  activation_646 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_646[0][0]']
#
#  activation_649 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_649[0][0]']
#
#  conv2d_645 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_647 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_646[0][0]']
#
#  conv2d_650 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_649[0][0]']
#
#  batch_normalization_645 (Batch  (None, 7, 7, 32)    96          ['conv2d_645[0][0]']
#  Normalization)
#
#  batch_normalization_647 (Batch  (None, 7, 7, 32)    96          ['conv2d_647[0][0]']
#  Normalization)
#
#  batch_normalization_650 (Batch  (None, 7, 7, 64)    192         ['conv2d_650[0][0]']
#  Normalization)
#
#  activation_645 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_645[0][0]']
#
#  activation_647 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_647[0][0]']
#
#  activation_650 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_650[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_645[0][0]',
#                                                                   'activation_647[0][0]',
#                                                                   'activation_650[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 7, 7, 320)    0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 7, 7, 320)    0           ['block35_5[0][0]']
#
#  conv2d_654 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_654 (Batch  (None, 7, 7, 32)    96          ['conv2d_654[0][0]']
#  Normalization)
#
#  activation_654 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_654[0][0]']
#
#  conv2d_652 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_655 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_654[0][0]']
#
#  batch_normalization_652 (Batch  (None, 7, 7, 32)    96          ['conv2d_652[0][0]']
#  Normalization)
#
#  batch_normalization_655 (Batch  (None, 7, 7, 48)    144         ['conv2d_655[0][0]']
#  Normalization)
#
#  activation_652 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_652[0][0]']
#
#  activation_655 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_655[0][0]']
#
#  conv2d_651 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_653 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_652[0][0]']
#
#  conv2d_656 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_655[0][0]']
#
#  batch_normalization_651 (Batch  (None, 7, 7, 32)    96          ['conv2d_651[0][0]']
#  Normalization)
#
#  batch_normalization_653 (Batch  (None, 7, 7, 32)    96          ['conv2d_653[0][0]']
#  Normalization)
#
#  batch_normalization_656 (Batch  (None, 7, 7, 64)    192         ['conv2d_656[0][0]']
#  Normalization)
#
#  activation_651 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_651[0][0]']
#
#  activation_653 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_653[0][0]']
#
#  activation_656 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_656[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_651[0][0]',
#                                                                   'activation_653[0][0]',
#                                                                   'activation_656[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 7, 7, 320)    0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 7, 7, 320)    0           ['block35_6[0][0]']
#
#  conv2d_660 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_660 (Batch  (None, 7, 7, 32)    96          ['conv2d_660[0][0]']
#  Normalization)
#
#  activation_660 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_660[0][0]']
#
#  conv2d_658 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_661 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_660[0][0]']
#
#  batch_normalization_658 (Batch  (None, 7, 7, 32)    96          ['conv2d_658[0][0]']
#  Normalization)
#
#  batch_normalization_661 (Batch  (None, 7, 7, 48)    144         ['conv2d_661[0][0]']
#  Normalization)
#
#  activation_658 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_658[0][0]']
#
#  activation_661 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_661[0][0]']
#
#  conv2d_657 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_659 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_658[0][0]']
#
#  conv2d_662 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_661[0][0]']
#
#  batch_normalization_657 (Batch  (None, 7, 7, 32)    96          ['conv2d_657[0][0]']
#  Normalization)
#
#  batch_normalization_659 (Batch  (None, 7, 7, 32)    96          ['conv2d_659[0][0]']
#  Normalization)
#
#  batch_normalization_662 (Batch  (None, 7, 7, 64)    192         ['conv2d_662[0][0]']
#  Normalization)
#
#  activation_657 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_657[0][0]']
#
#  activation_659 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_659[0][0]']
#
#  activation_662 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_662[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_657[0][0]',
#                                                                   'activation_659[0][0]',
#                                                                   'activation_662[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 7, 7, 320)    0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 7, 7, 320)    0           ['block35_7[0][0]']
#
#  conv2d_666 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_666 (Batch  (None, 7, 7, 32)    96          ['conv2d_666[0][0]']
#  Normalization)
#
#  activation_666 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_666[0][0]']
#
# ...
#  block8_7 (Lambda)              (None, 1, 1, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_801 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_801 (Batch  (None, 1, 1, 192)   576         ['conv2d_801[0][0]']
#  Normalization)
#
#  activation_801 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_801[0][0]']
#
#  conv2d_802 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_801[0][0]']
#
#  batch_normalization_802 (Batch  (None, 1, 1, 224)   672         ['conv2d_802[0][0]']
#  Normalization)
#
#  activation_802 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_802[0][0]']
#
#  conv2d_800 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_803 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_802[0][0]']
#
#  batch_normalization_800 (Batch  (None, 1, 1, 192)   576         ['conv2d_800[0][0]']
#  Normalization)
#
#  batch_normalization_803 (Batch  (None, 1, 1, 256)   768         ['conv2d_803[0][0]']
#  Normalization)
#
#  activation_800 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_800[0][0]']
#
#  activation_803 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_803[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_800[0][0]',
#                                                                   'activation_803[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 1, 1, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_805 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_805 (Batch  (None, 1, 1, 192)   576         ['conv2d_805[0][0]']
#  Normalization)
#
#  activation_805 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_805[0][0]']
#
#  conv2d_806 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_805[0][0]']
#
#  batch_normalization_806 (Batch  (None, 1, 1, 224)   672         ['conv2d_806[0][0]']
#  Normalization)
#
#  activation_806 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_806[0][0]']
#
#  conv2d_804 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_807 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_806[0][0]']
#
#  batch_normalization_804 (Batch  (None, 1, 1, 192)   576         ['conv2d_804[0][0]']
#  Normalization)
#
#  batch_normalization_807 (Batch  (None, 1, 1, 256)   768         ['conv2d_807[0][0]']
#  Normalization)
#
#  activation_804 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_804[0][0]']
#
#  activation_807 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_807[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_804[0][0]',
#                                                                   'activation_807[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 1, 1, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_809 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_809 (Batch  (None, 1, 1, 192)   576         ['conv2d_809[0][0]']
#  Normalization)
#
#  activation_809 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_809[0][0]']
#
#  conv2d_810 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_809[0][0]']
#
#  batch_normalization_810 (Batch  (None, 1, 1, 224)   672         ['conv2d_810[0][0]']
#  Normalization)
#
#  activation_810 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_810[0][0]']
#
#  conv2d_808 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_811 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_810[0][0]']
#
#  batch_normalization_808 (Batch  (None, 1, 1, 192)   576         ['conv2d_808[0][0]']
#  Normalization)
#
#  batch_normalization_811 (Batch  (None, 1, 1, 256)   768         ['conv2d_811[0][0]']
#  Normalization)
#
#  activation_808 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_808[0][0]']
#
#  activation_811 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_811[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 1, 448)    0           ['activation_808[0][0]',
#                                                                   'activation_811[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 1, 1, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 1, 1, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 1, 1, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten_3 (Flatten)            (None, 1536)         0           ['conv_7b_ac[0][0]']
#
#  dense_3 (Dense)                (None, 256)          393472      ['flatten_3[0][0]']
#
#  fc (Dense)                     (None, 1)            257         ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 54,730,465
# Trainable params: 54,659,777
# Non-trainable params: 70,688
# __________________________________________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 75s 367ms/step - loss: 0.7444 - accuracy: 0.7783 - val_loss: 3.1494 - val_accuracy: 0.5600
# Epoch 2/20
# 19/19 [==============================] - 3s 181ms/step - loss: 0.2380 - accuracy: 0.9150 - val_loss: 0.4911 - val_accuracy: 0.7667
# Epoch 3/20
# 19/19 [==============================] - 3s 172ms/step - loss: 0.1298 - accuracy: 0.9567 - val_loss: 0.2542 - val_accuracy: 0.8600
# Epoch 4/20
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0927 - accuracy: 0.9700 - val_loss: 0.3281 - val_accuracy: 0.8400
# Epoch 5/20
# 19/19 [==============================] - 4s 206ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 0.0721 - val_accuracy: 0.9867
# Epoch 6/20
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0354 - accuracy: 0.9867 - val_loss: 0.1636 - val_accuracy: 0.9400
# Epoch 7/20
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.0836 - val_accuracy: 0.9733
# Epoch 8/20
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0157 - accuracy: 0.9967 - val_loss: 0.7198 - val_accuracy: 0.8667
# Epoch 9/20
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0615 - accuracy: 0.9817 - val_loss: 1.2450 - val_accuracy: 0.9067
# Epoch 10/20
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 1.0015 - val_accuracy: 0.9267
# Epoch 11/20
# 19/19 [==============================] - 3s 173ms/step - loss: 0.1077 - accuracy: 0.9817 - val_loss: 0.1440 - val_accuracy: 0.9533
# Epoch 12/20
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9733
# Epoch 13/20
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0670 - val_accuracy: 0.9867
# Epoch 14/20
# 19/19 [==============================] - 4s 185ms/step - loss: 0.0183 - accuracy: 0.9983 - val_loss: 0.0756 - val_accuracy: 0.9800
# Epoch 15/20
# 19/19 [==============================] - 3s 185ms/step - loss: 0.0107 - accuracy: 0.9983 - val_loss: 0.1022 - val_accuracy: 0.9800
# Epoch 16/20
# 19/19 [==============================] - 4s 190ms/step - loss: 3.1184e-04 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9867
# Epoch 17/20
# 19/19 [==============================] - 3s 171ms/step - loss: 5.1649e-04 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9733
# Epoch 18/20
# 19/19 [==============================] - 3s 171ms/step - loss: 4.8116e-05 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9867
# Epoch 19/20
# 19/19 [==============================] - 4s 203ms/step - loss: 2.3031e-05 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9867
# Epoch 20/20
# 17/19 [=========================>....] - ETA: 0s - loss: 1.6290e-05 - accuracy: 1.0000

# %%
test_untrained_CNN_App(100)

# %%
test_pretrained_CNN_App(20)

# %%
test_pretrained_layers_freezing_CNN_App(20)

# %% [markdown]
# ## 3.3 Conclusion

# %% [markdown]
# That's it! Congratulations on training CNN use cases models.
#
# Make sure you deliver all the requirements for the submission.
